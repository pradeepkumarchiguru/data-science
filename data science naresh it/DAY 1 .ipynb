# %% [markdown]
# # comment
# - able to understand the code in easy way
# # variable
# - it stores the value in the memory
# -
# it creat one object & inside the value will be stored

# %%
# variable 
a=11

# %% [markdown]
# # rules for declaring variable

# %%
a=900

# %%
a1=90

# %%
a_=10

# %%
_9=90

# %% [markdown]
# **syntax error**

# %%
9a=10 # wrong sintax
# Out:
#   Cell In[9], line 1
#     9a=10 # wrong sintax
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # values

# %%
24 # here printed
# Out:
# 24

# %% [markdown]
# - in the jupiter not book the last line will be printed or it will be stored

# %%
a=24  # here it is stored

# %%
"srk"
# Out:
# 'srk'

# %%
'srk'
# Out:
# 'srk'

# %%
a=25.4

# %% [markdown]
# # shortcut
# - esc+m to convert any cell to markdown

# %% [markdown]
# - print(value)
# - print (variable)
# - print (v1 , v2)

# %%
print(29)
# Out:
# 29

# %%
print("ds")
# Out:
# ds

# %%
print("ds","srk ") # by defult it gives space between values
# Out:
# ds srk

# %%
a=20
b=10
print(a,b)
# Out:
# 20 10

# %%
print(a,           b)
# Out:
# 20 10

# %%
print('sam')
# Out:
# sam

# %%
print("sam ")
# Out:
# sam

# %%
'sam'
# Out:
# 'sam'

# %%
a="sam"

# %%
a
# Out:
# 'sam'

# %%
a='sam'
a
# Out:
# 'sam'

# %% [markdown]
# # multiple variable assignment

# %%
a,b=30,20

# %%
a 
b
# Out:
# 20

# %%
a=b=c=10

# %%
a,b,c  # tuple
# Out:
# (10, 10, 10)

# %%
print(a,b,c, sep="*")
# Out:
# 10*10*10

# %%
a=20

# %%
a=40

# %%
a  # deleted the perious value
# Out:
# 40

# %%
del a   # delet the a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a=10
b=10

del a,b

# %%
a,b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 a,b
#
# NameError: name 'a' is not defined

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 b
#
# NameError: name 'b' is not defined
